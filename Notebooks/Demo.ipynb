# %%
import msi_workflow as maspim

# %% [markdown]
# # Getting the test data set

# %%
path_folder = r'C:\Users\Yannick Zander\Promotion\Cariaco MSI 2024\484-485cm\2018_08_23 Cariaco 484-485 alkenones 100 um .i'
project = maspim.get_project(is_MSI=True, path_folder=path_folder)

# %% [markdown]
# # Creating image objects
#
# Ideally this is just as simple as calling this function. However, for special cases it is possible to control individual steps and to modify parameters which we will look into more in the following paragraph

# %%
plts = True
project.require_images(overwrite=False)
if plts:
    project.plot_overview()
# Out:
# region_in_box expects grayscale image, converted input to grayscale
# (6844, 16408)
