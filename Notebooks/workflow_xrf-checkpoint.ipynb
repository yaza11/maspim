# %% [markdown]
# # Import modules

# %%
from Project.cProject import Project

import logging

logging.basicConfig(level=logging.INFO)  # get some info during runtime

# %% [markdown]
#  # Set some parameters

# %%
path_folder = r'C:\Users\Yannick Zander\Promotion\Cariaco line scan Xray\uXRF slices\S0343b_485-490cm'
# depth_span = (485, 490)
import os
u, l = os.path.split(path_folder)[1].split('_')[1].split('-')
depth_span = (int(u), int(l[:-2]))
print(depth_span)
# Out:
# (485, 490)

# %% [markdown]
# # Set the age model (combination of two shorter ones)

# %%
from data.cAgeModel import AgeModel

path_age_model_480_510 = r'C:/Users/Yannick Zander/Promotion/Cariaco MSI 2024/Age Model/480-510/480_510_MSI_age_model_mm_yr.txt'
path_age_model_510_540 = r'C:/Users/Yannick Zander/Promotion/Cariaco MSI 2024/Age Model/510-540/510_540_MSI_age_model_mm_yr.txt'

age_model_480_510 = AgeModel(path_age_model_480_510, depth_offset=4800, conversion_to_cm=1 / 10, sep='\t',
                             index_col=False)
age_model_510_540 = AgeModel(path_age_model_510_540, depth_offset=5100, conversion_to_cm=1 / 10, sep='\t',
                             index_col=False)

age_model = age_model_480_510 + age_model_510_540

# %%
age_model
# Out:
#            depth      age
# 0     480.089992  11194.2
# 1     480.099992  11194.4
# 2     480.109991  11194.6
# 3     480.119990  11194.8
# 4     480.129989  11195.0
# ...          ...      ...
# 5949  539.926400  11930.6
# 5950  539.936400  11930.7
# 5951  539.946400  11930.7
# 5952  539.956400  11930.8
# 5953  539.966400  11930.9
#
# [5954 rows x 2 columns]

# %% [markdown]
# # Initialize the project

# %%
p = Project(is_MSI=False, path_folder=path_folder)

# %% [markdown]
# path_bcf_file, path_image_file and path_image_roi_file should match the desired files, if not, provide them as keyword arguments! The measurement name is infered from the folder name but is only relevant if multiple exports are found in the folder. If a project was created earlier for this measurement, additional files such as SampleImageHanderXRF_file will show up as well

# %%
p.__dict__
# Out:
# {'path_folder': 'C:\\Users\\Yannick Zander\\Promotion\\Cariaco line scan Xray\\uXRF slices\\S0343b_485-490cm',
#  'path_d_folder': 'C:\\Users\\Yannick Zander\\Promotion\\Cariaco line scan Xray\\uXRF slices\\S0343b_485-490cm',
#  'measurement_name': 'S0343b',
#  'path_bcf_file': 'C:\\Users\\Yannick Zander\\Promotion\\Cariaco line scan Xray\\uXRF slices\\S0343b_485-490cm\\Cariaco_485-490cm_100µm_BB_20180518.bcf',
#  'path_image_file': 'C:\\Users\\Yannick Zander\\Promotion\\Cariaco line scan Xray\\uXRF slices\\S0343b_485-490cm\\Caricao_485-490cm_100µm_Mosaic.tif',
#  'path_image_roi_file': 'C:\\Users\\Yannick Zander\\Promotion\\Cariaco line scan Xray\\uXRF slices\\S0343b_485-490cm\\D0343b_Video 1.txt',
#  'ImageROI_file': 'ImageROI.pickle',
#  'ImageSample_file': 'ImageSample.pickle',
#  'SampleImageHandlerXRF_file': 'SampleImageHandlerXRF.pickle'}

# %% [markdown]
# set depth and age interval

# %%
p.set_depth_span(depth_span)
p.age_model = age_model
p.set_age_span()

print(f'depth span: {p.depth_span} cm')
print(f' age span: {p.age_span} kyrs b2k')
# Out:
# depth span: (485, 490) cm
#  age span: (11293.0084, 11393.916733067728) kyrs b2k

# %% [markdown]
# # set the images

# %%
p.set_image_handler()
p.image_handler.plot_extent_data()

# %% [markdown]
# # set image sample object
# if the obj color is not identified correctly, specify it (foreground pixels should be white) \n
# if the roi is not detected correctly, call the function again with overwrite=True and interactive=True

# %%
p.set_image_sample(obj_color='light', overwrite=False)
# p.set_image_sample(obj_color='light', overwrite=True, interactive=True)
# Out:
# INFO:Project.cProject:loading ImageSample
# INFO:msi_workflow.util.cClass:loading object with keys dict_keys(['obj_color', '_hw', 'path_folder', '_xywh_ROI'])

# %%
p.image_sample.plot_overview()
# Out:
# INFO:msi_workflow-imaging.util.Image_helpers:Determining threshold for background intensity with OTSU.
# INFO:msi_workflow.imaging.main.cImage:searching optimal parameters for box
# INFO:msi_workflow.imaging.main.cImage:found box with [9.66083546e-01 3.81668946e-01 4.79500252e+02 3.39499949e+02]
# INFO:msi_workflow.imaging.main.cImage:solver converged: True
# INFO:msi_workflow-imaging.util.Image_helpers:Determining threshold for background intensity with OTSU.

# %% [markdown]
# # set the ROI object
# (uses the final sample region from the previous plot)

# %%
p.set_image_roi()
# p.image_roi.set_punchholes(side='bottom')
# p.image_roi.set_punchholes(interactive=True)
p.image_roi.save()  # save changes
# Out:
# INFO:Project.cProject:loading ImageROI
# INFO:msi_workflow.util.cClass:loading object with keys dict_keys(['obj_color', '_hw', '_image_original', 'path_folder', 'age_span', '_image_classification', '_params'])
# INFO:msi_workflow.util.cClass:saving image object with dict_keys(['obj_color', '_hw', '_image_original', 'path_folder', 'age_span', '_image_classification', '_params']) to C:\Users\Yannick Zander\Promotion\Cariaco line scan Xray\uXRF slices\S0343b_485-490cm

# %%
p.image_roi.plot_overview()
# Out:
# WARNING:msi_workflow.imaging.main.cImage:Punchholes not set with required parameter 'remove_gelatine', this may affect performance.
# INFO:msi_workflow-imaging.util.Image_helpers:Determining threshold for background intensity with OTSU.
# INFO:msi_workflow.imaging.misc.find_punch_holes:found holes at bottom
# INFO:msi_workflow.imaging.main.cImage:Estimating kernel size from age model (square with 2x expected thickness of one year).
# 49.120000000000005

# %%
print(p.image_roi.image_classification.shape)
print(p.image_roi.image_grayscale.shape)
print(p.image_roi.mask_foreground.shape)
import matplotlib.pyplot as plt
plt.imshow(p.image_roi.image_classification)
# Out:
# (325, 1228)
# (325, 1228)
# (325, 1228)

# %% [markdown]
# # set the classified image

# %%
p.set_image_classified()
# Out:
# INFO:Project.cProject:setting laminae in ImageClassified ...
# INFO:msi_workflow.imaging.main.cImage:setting seeds
# INFO:msi_workflow-imaging.util.Image_helpers:Determining threshold for background intensity with OTSU.
# INFO:msi_workflow.imaging.main.cImage:finding distorted rects
# searching parameters for 97 light laminae ...
# estimated time left:  0.0 sec
# searching parameters for 96 dark laminae ...
# estimated time left:  0.2 sec
# INFO:msi_workflow.imaging.main.cImage:creating image
# INFO:msi_workflow.imaging.main.cImage:calculating quality score
# estimated time left:  0.0 sec
# C:\Users\Yannick Zander\Nextcloud2\Promotion\msi_workflow\imaging\main\cImage.py:1512: RuntimeWarning: invalid value encountered in scalar divide
#   homogeneity = (sum_lights - sum_darks) / (sum_lights + sum_darks)
# C:\Users\Yannick Zander\Nextcloud2\Promotion\msi_workflow\imaging\main\cImage.py:1516: RuntimeWarning: invalid value encountered in scalar divide
#   continuity = np.sum(mask_valid) / np.sum(mask_extent)
# C:\Users\Yannick Zander\Nextcloud2\Promotion\msi_workflow\imaging\main\cImage.py:1520: RuntimeWarning: invalid value encountered in divide
#   brightness = np.sum(region_grayscale * mask_valid) / np.sum(mask_valid)
# WARNING:msi_workflow.imaging.main.cImage:zeropadded regionto be square shape
# WARNING:msi_workflow.imaging.main.cImage:shape before: (325, 323)
# INFO:msi_workflow.imaging.main.cImage:shape after: (325, 325)
# WARNING:msi_workflow.imaging.main.cImage:zeropadded regionto be square shape
# WARNING:msi_workflow.imaging.main.cImage:shape before: (325, 323)
# INFO:msi_workflow.imaging.main.cImage:shape after: (325, 325)
# INFO:msi_workflow.util.cClass:saving image object with dict_keys(['obj_color', '_hw', '_image_original', 'path_folder', '_image_classification', 'age_span', 'params_laminae_simplified', 'image_seeds']) to C:\Users\Yannick Zander\Promotion\Cariaco line scan Xray\uXRF slices\S0343b_485-490cm

# %%
p.image_classified.params_laminae_simplified
# Out:
#      seed         a         b         c         d     height  success  color  \
# 0       0  0.000000  0.000000  0.000000  0.000000   2.320045     True  light
# 1       0  0.000000  0.000000  0.000000  0.000000   1.100000     True   dark
# 2      16 -0.001308  0.003333 -0.033184 -0.020739  42.228946     True   dark
# 3      16  0.000000  0.000000  0.000000  0.000000   3.701102     True  light
# 4      32  0.000000  0.000000  0.000000  0.000000   2.901071     True   dark
# ..    ...       ...       ...       ...       ...        ...      ...    ...
# 188  1200  0.000000  0.000000  0.000000  0.000000   1.511087     True   dark
# 189  1200  0.000000  0.000000  0.000000  0.000000   1.238785     True  light
# 190  1216  0.000000  0.000000  0.000000  0.000000   2.062452     True   dark
# 191  1216 -0.011110  0.011015 -0.033265  0.002758  37.364192     True  light
# 192  1232  0.000000  0.000000  0.000000  0.000000   0.984949     True  light
#
#          width  prominence  homogeneity  continuity  brightness  contrast  \
# 0     2.320045    0.357537          NaN         NaN         NaN       NaN
# 1     1.100000    0.500000          NaN         NaN         NaN       NaN
# 2    21.114473    0.357537    -0.027178    0.630068  133.649480       NaN
# 3     3.701102    0.159931     0.085714    0.675676  136.148571 -0.010418
# 4     2.901071    0.121417     0.452381    0.800000  144.380952  0.016956
# ..         ...         ...          ...         ...         ...       ...
# 188   1.511087    0.100347     0.037383    0.918455  160.742991 -0.013405
# 189   1.238785    0.100347     0.037383    0.918455  160.742991 -0.003275
# 190   2.062452    0.198680     0.226804    0.881818  162.855670  0.006568
# 191  18.682096    0.619264     0.133579    0.748246  160.717777       NaN
# 192   0.984949    0.192699          NaN         NaN         NaN       NaN
#
#       quality
# 0         NaN
# 1         NaN
# 2         NaN
# 3   -0.000603
# 4    0.006136
# ..        ...
# 188 -0.000460
# 189 -0.000112
# 190  0.001314
# 191       NaN
# 192       NaN
#
# [193 rows x 15 columns]

# %%
p.image_classified.plot_overview()

# %%
p.image_classified.params_laminae_simplified
# Out:
#      seed         a         b         c         d     height  success  color  \
# 0       0  0.000000  0.000000  0.000000  0.000000   2.320045     True  light
# 1       0  0.000000  0.000000  0.000000  0.000000   1.100000     True   dark
# 2      16 -0.001308  0.003333 -0.033184 -0.020739  42.228946     True   dark
# 3      16  0.000000  0.000000  0.000000  0.000000   3.701102     True  light
# 4      32  0.000000  0.000000  0.000000  0.000000   2.901071     True   dark
# ..    ...       ...       ...       ...       ...        ...      ...    ...
# 188  1200  0.000000  0.000000  0.000000  0.000000   1.511087     True   dark
# 189  1200  0.000000  0.000000  0.000000  0.000000   1.238785     True  light
# 190  1216  0.000000  0.000000  0.000000  0.000000   2.062452     True   dark
# 191  1216 -0.011110  0.011015 -0.033265  0.002758  37.364192     True  light
# 192  1232  0.000000  0.000000  0.000000  0.000000   0.984949     True  light
#
#          width  prominence  homogeneity  continuity  brightness  contrast  \
# 0     2.320045    0.357537          NaN         NaN         NaN       NaN
# 1     1.100000    0.500000          NaN         NaN         NaN       NaN
# 2    21.114473    0.357537    -0.027178    0.630068  133.649480       NaN
# 3     3.701102    0.159931     0.085714    0.675676  136.148571 -0.010418
# 4     2.901071    0.121417     0.452381    0.800000  144.380952  0.016956
# ..         ...         ...          ...         ...         ...       ...
# 188   1.511087    0.100347     0.037383    0.918455  160.742991 -0.013405
# 189   1.238785    0.100347     0.037383    0.918455  160.742991 -0.003275
# 190   2.062452    0.198680     0.226804    0.881818  162.855670  0.006568
# 191  18.682096    0.619264     0.133579    0.748246  160.717777       NaN
# 192   0.984949    0.192699          NaN         NaN         NaN       NaN
#
#       quality
# 0         NaN
# 1         NaN
# 2         NaN
# 3   -0.000603
# 4    0.006136
# ..        ...
# 188 -0.000460
# 189 -0.000112
# 190  0.001314
# 191       NaN
# 192       NaN
#
# [193 rows x 15 columns]

# %%
colors = p.image_classified.params_laminae_simplified.color
print(f'found {sum(colors == "light")} light and {sum(colors == "dark")} laminae')
print(f'whereas the age model predicts {round(p.age_span[1] - p.age_span[0])}')
# Out:
# found 97 light and 96 laminae
# whereas the age model predicts 101

# %% [markdown]
# # set measurement
# by default, this object also has information about the photo

# %%
p.set_data_object()

# %%
p.data_object.feature_table
# Out:
#         Al  Br   Ca  Cl  Cr  Fe  K  Mg  Mn  Na  ...  S   Si  Sr  Ti  V      L  \
# 0        0   8  102   2   0  15  6   0   2   0  ...  0  119   0   2  0   5101
# 1        4   5   88   1   2   8  3   2   3   1  ...  2  113   6   0  0   4770
# 2        1   7   81   1   1   7  9   2   2   1  ...  0  110   9   1  2   5868
# 3        0   9   92   4   1  16  2   2   5   1  ...  1  116   7   1  0   5939
# 4        3   3   79   7   3   9  8   5   3   1  ...  1  101   8   1  1   6046
# ...     ..  ..  ...  ..  ..  .. ..  ..  ..  ..  ... ..  ...  ..  .. ..    ...
# 316395   2   5   90   4   0   6  2   3   2   3  ...  2  104   8   0  0  10597
# 316396   1   3   82   6   0   7  9   1   6   0  ...  4  114   9   2  0  10985
# 316397   1   3   92   1   2  11  9   1   4   2  ...  2  134  11   2  2   9842
# 316398   1   8   83   5   8   3  7   2   0   1  ...  2  125   3   2  0   7534
# 316399   0   5   77   4   1   2  3   1   6   1  ...  0  104   8   2  1   6462
#
#            x    y  Zn  R
# 0          0    0   0  0
# 1          1    0   4  0
# 2          2    0   3  0
# 3          3    0   2  0
# 4          4    0   1  0
# ...      ...  ...  .. ..
# 316395  1125  279   5  0
# 316396  1126  279   4  0
# 316397  1127  279   7  0
# 316398  1128  279  11  0
# 316399  1129  279  11  0
#
# [316400 rows x 22 columns]

# %%
p.data_object.plot_comp('L')
# Out:
# WARNING:msi_workflow.data.cDataClass:did not find the column valid in the feature table classifying the holes, so not excluding pixels
# INFO:msi_workflow.data.cDataClass:not clipping values

# %% [markdown]
# # add image related attributes to the data table

# %%
p.add_pixels_ROI()
p.add_photo()
p.add_holes()
p.add_depth_column(exclude_gaps=True)
p.add_age_column()
p.add_light_dark_classification()
p.add_laminae_classification()

# %%
p.data_object.plot_comp('classification_s')
p.data_object.plot_comp('classification_se')
# Out:
# INFO:msi_workflow.data.cDataClass:not clipping values
# INFO:msi_workflow.data.cDataClass:not clipping values

# %%
p.data_object.feature_table.columns
# Out:
# Index(['Al', 'Br', 'Ca', 'Cl', 'Cr', 'Fe', 'K', 'Mg', 'Mn', 'Na', 'P', 'Rh',
#        'S', 'Si', 'Sr', 'Ti', 'V', 'L', 'x', 'y', 'Zn', 'R', 'x_ROI', 'y_ROI',
#        'valid', 'depth', 'age', 'classification', 'classification_s',
#        'classification_se'],
#       dtype='object')

# %%
p.data_object.plot_comp('L')
# Out:
# INFO:msi_workflow.data.cDataClass:not clipping values

# %% [markdown]
# # set time series based on laminae classification

# %%
p.set_time_series(average_by_col='classification_se', overwrite=True)
# Out:
# INFO:msi_workflow.util.cClass:saving image object with dict_keys(['path_folder', 'feature_table', 'successes', 'deviations']) to C:\Users\Yannick Zander\Promotion\Cariaco line scan Xray\uXRF slices\S0343b_485-490cm

# %%
import numpy as np
np.isnan(p.time_series.feature_table.quality.to_numpy()).sum()
# Out:
# 0

# %% [markdown]
# # look at a few examples

# %%
p.time_series.plot_comp('Fe', color_seasons=True)
p.time_series.plot_comp('Si', color_seasons=True)
